# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
rand = torch.rand(224, 224, 3) #height, width and color channels
rand
# Out:
# tensor([[[0.1956, 0.6402, 0.7511],
#          [0.3649, 0.6727, 0.4055],
#          [0.4416, 0.5373, 0.2678],
#          ...,
#          [0.5417, 0.6270, 0.4899],
#          [0.0593, 0.4340, 0.3496],
#          [0.8615, 0.5142, 0.2000]],
#
#         [[0.4234, 0.5803, 0.6191],
#          [0.8046, 0.7939, 0.9100],
#          [0.2114, 0.4406, 0.8048],
#          ...,
#          [0.5705, 0.0038, 0.1448],
#          [0.4507, 0.5876, 0.3041],
#          [0.8843, 0.2158, 0.7578]],
#
#         [[0.1361, 0.8587, 0.5183],
#          [0.5318, 0.1720, 0.7775],
#          [0.1778, 0.6325, 0.3381],
#          ...,
#          [0.0581, 0.0771, 0.5710],
#          [0.2099, 0.4463, 0.4974],
#          [0.3127, 0.9662, 0.4059]],
#
#         ...,
#
#         [[0.5108, 0.8832, 0.5938],
#          [0.2109, 0.6848, 0.6035],
#          [0.3464, 0.0066, 0.3266],
#          ...,
#          [0.3229, 0.4275, 0.8758],
#          [0.9893, 0.4033, 0.5978],
#          [0.8433, 0.3043, 0.2035]],
#
# ...
